# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
raw_data1=pd.read_csv('orders.csv')
raw_data1
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
raw_data=pd.read_csv('order_items.csv')
raw_data
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
selected_seller_id='48436dade18ac8b2bce089ec2a041202'
seller_orders=raw_data.loc[raw_data['seller_id']==selected_seller_id]
seller_orders
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 660     0188777fe321843a18be24a6e9aa1e53              1
# 669     0191bbb5166d4b9a68df11797d5acfa9              1
# 1295    03054d8a8eefc2981cfad06f58e27979              1
# 5376    0c325ea6925de749e1420be0cf43587c              1
# ...                                  ...            ...
# 106715  f28b59f3a9d27b5a7ea86d0ede1b99d0              1
# 109487  f8da7d096b125f74ad5b784140c294c7              1
# 109908  f9c50aff44ed91808d5b511bd49106ec              1
# 110207  fa68c8eaee429c95ac88e1034d583057              1
# 110882  fbf096edf8034d915770443bb21bfad4              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 660     436c8d57ff8d4aa254318e9bd9b48c83  48436dade18ac8b2bce089ec2a041202
# ...

# %%
seller_orders_new=pd.DataFrame()
seller_orders_new['Orders']=seller_orders['order_id']
seller_orders_new
# Out:
#                                   Orders
# 0       00010242fe8c5a6d1ba2dd792cb16214
# 660     0188777fe321843a18be24a6e9aa1e53
# 669     0191bbb5166d4b9a68df11797d5acfa9
# 1295    03054d8a8eefc2981cfad06f58e27979
# 5376    0c325ea6925de749e1420be0cf43587c
# ...                                  ...
# 106715  f28b59f3a9d27b5a7ea86d0ede1b99d0
# 109487  f8da7d096b125f74ad5b784140c294c7
# 109908  f9c50aff44ed91808d5b511bd49106ec
# 110207  fa68c8eaee429c95ac88e1034d583057
# 110882  fbf096edf8034d915770443bb21bfad4
#
# [151 rows x 1 columns]

# %%
sellers_dates=pd.DataFrame(columns=[['delivered','estimated']])
for ind in raw_data1.index:
    if(ind in seller_orders.index):
        sellers_dates.loc[ len(sellers_dates.index )] = [raw_data1['order_delivered_customer_date'][ind],raw_data1['order_estimated_delivery_date'][ind]]
sellers_dates
# Out:
#                delivered            estimated
# 0    2017-10-10 21:25:13  2017-10-18 00:00:00
# 1    2018-04-24 14:31:22  2018-05-09 00:00:00
# 2    2017-07-25 19:42:50  2017-07-27 00:00:00
# 3    2018-07-04 20:32:36  2018-07-19 00:00:00
# 4    2018-02-16 22:18:58  2018-02-16 00:00:00
# ..                   ...                  ...
# 131  2017-07-06 17:13:30  2017-07-18 00:00:00
# 132  2018-05-07 17:03:43  2018-05-11 00:00:00
# 133  2017-11-07 21:45:33  2017-11-28 00:00:00
# 134  2018-04-16 20:16:26  2018-05-07 00:00:00
# 135  2018-01-13 17:57:37  2018-01-24 00:00:00
#
# [136 rows x 2 columns]

# %%
def days_between(d1, d2):
    if(str(d1)=='nan' or str(d2)=='nan'):return 0
    d1 = datetime.strptime(str(d1), "%Y-%m-%d %H:%M:%S")
    d2 = datetime.strptime(str(d2), "%Y-%m-%d %H:%M:%S")
    return abs((d2 - d1).days)

# %%
from datetime import datetime
#arr=sellers_dates['delivered']-sellers_dates['estimated']
#delta=sellers_dates['delivered'][0]-sellers_dates['estimated'][0]
delta=[]
for ind in sellers_dates.index:
    delta.append(days_between(sellers_dates.iloc[ind:ind+1]['delivered'].values[0][0],sellers_dates.iloc[ind:ind+1]['estimated'].values[0][0]))
delta
# Out:
# [7,
#  14,
#  1,
#  14,
#  1,
#  0,
#  1,
#  19,
#  3,
#  8,
#  36,
#  13,
#  0,
#  10,
#  3,
#  0,
#  3,
#  13,
#  23,
#  6,
#  3,
#  18,
#  19,
#  13,
#  15,
#  21,
#  10,
#  5,
#  15,
#  10,
#  12,
#  0,
#  3,
#  7,
#  22,
#  0,
#  12,
#  14,
#  7,
#  4,
#  13,
#  6,
#  9,
#  16,
#  15,
#  14,
#  4,
#  0,
#  0,
#  12,
#  12,
#  14,
#  13,
#  6,
#  8,
#  1,
#  17,
#  16,
#  10,
#  6,
#  17,
#  7,
#  11,
#  7,
#  4,
#  8,
#  1,
#  16,
#  11,
#  14,
#  17,
#  11,
#  14,
#  8,
#  9,
#  11,
#  23,
#  15,
#  25,
#  10,
#  14,
#  11,
#  10,
#  6,
#  6,
#  18,
#  3,
#  0,
#  9,
#  4,
#  9,
#  7,
#  12,
#  12,
#  16,
#  10,
#  20,
#  0,
#  10,
#  8,
#  13,
#  22,
#  10,
#  22,
#  22,
#  4,
#  11,
#  15,
#  24,
#  12,
#  31,
#  10,
#  4,
#  15,
#  23,
#  8,
#  0,
#  2,
#  17,
#  6,
#  18,
#  12,
#  14,
#  13,
#  10,
#  10,
#  7,
#  18,
#  5,
#  6,
#  13,
#  11,
#  3,
#  20,
#  20,
#  10]

# %%
sum=0
for i in delta:
    sum+=i
forecasted_amount_of_days=sum/len(delta)
forecasted_amount_of_days
round(forecasted_amount_of_days,0)
# Out:
# 11.0
